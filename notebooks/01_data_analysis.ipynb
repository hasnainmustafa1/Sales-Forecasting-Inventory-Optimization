# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/retail_sales.csv', parse_dates=['date'])
df.groupby('date')['units_sold'].sum().plot(figsize=(10,4))
plt.show()
